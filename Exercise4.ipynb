# %% [markdown]
# <a href="https://colab.research.google.com/github/teejx/CCMACLRL_EXERCISES_COM222ML/blob/main/Exercise4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise 4
#
# **Instructions:**
#
# Build a Simple Linear Regression model to study the linear relationship between the years of experience and salary.
#
# <img src="https://media2.giphy.com/media/67ThRZlYBvibtdF9JH/200w.gif?cid=6c09b952x78udp8ynvf71q2iximtwq0egwludug1qo7qgla2&ep=v1_gifs_search&rid=200w.gif&ct=g">

# %% [markdown]
# 1. Import the necessary packages

# %%
# put your answer here
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %% [markdown]
# 2. Load the salary.csv file

# %%
# put your answer here
df = pd.read_csv("salary.csv")

# %% [markdown]
# 3. Print the first 5 rows of the dataset

# %%
# put your answer here
df.head()
# Out:
#    YearsExperience  Salary
# 0              1.2   39344
# 1              1.4   46206
# 2              1.6   37732
# 3              2.1   43526
# 4              2.3   39892

# %% [markdown]
# 4. Display the general information of the dataframe

# %%
# put your answer here
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 608.0 bytes
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.413333   76004.000000
# std           2.837888   27414.429785
# min           1.200000   37732.000000
# 25%           3.300000   56721.750000
# 50%           4.800000   65238.000000
# 75%           7.800000  100545.750000
# max          10.600000  122392.000000

# %% [markdown]
# 5. Visualize the data by creating a scatter plot

# %%
# put your answer here

df.plot(x='YearsExperience',y='Salary',kind='scatter')
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %% [markdown]
# 6. Split the dataset into a training set and test set

# %%
# put answer here
X = df['YearsExperience'].values
y = df['Salary'].values

# Reshape X from a one dimensional array into a two dimensional array
X = X.reshape(-1,1)

# Reshape X from a one dimensional array into a two dimensional array
y = y.reshape(-1,1)

X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=0.33, random_state=42)

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (20, 1)
# (20, 1)
# (10, 1)
# (10, 1)

# %% [markdown]
# 7. Create an new instance of a linear regression model

# %%
# put your answer here
lr_model = LinearRegression()

# %% [markdown]
# 8. Train and test the model using the training set and test set

# %%
# put your answer here
lr_model.fit(X_train,y_train)
y_pred = lr_model.predict(X_test)

# %% [markdown]
# 9. Print the equation of the line
#
# - Display the slope
# - Display the intercept
# - Display the equation of the line

# %%
# Slope
m = lr_model.coef_[0]
m = m[0]

# Intercept
b = lr_model.intercept_[0]

print("b = ", b)
print("m = ", m)
print("y = ", m, "* x + ", b)
# Out:
# b =  24382.731502336872
# m =  9426.038769074832
# y =  9426.038769074832 * x +  24382.731502336872

# %% [markdown]
# 10. Draw the Regression Line

# %%
# put your answer here
plt.scatter(X, y, color = 'blue', label='Data Points')
plt.plot(X_test, y_pred, color = 'red', linewidth=3, label = 'Regression Line')
plt.title('Relationship between YearsExperience and Salary')
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
plt.legend(loc=4)
plt.show()

# %% [markdown]
# 11. Compute the Sum of Square Error (SSE)

# %%
# put your answer here
y_test = y_test.reshape(-1)
y_pred = y_pred.reshape(-1)

df1 = pd.DataFrame({'YearsExperience': y_test, 'Salary':y_pred})
df1.head()
# Out:
#    YearsExperience         Salary
# 0           112636  115815.307562
# 1            67939   71512.925348
# 2           113813  102618.853286
# 3            83089   75283.340855
# 4            64446   55488.659440

# %%
years_experience = np.array([[3]])
predicted_salary = lr_model.predict(years_experience)
print("Predicted Salary for 3 years of experience:", predicted_salary[0][0])
# Out:
# Predicted Salary for 3 years of experience: 52660.84780956137
