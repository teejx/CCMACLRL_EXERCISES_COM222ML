# %% [markdown]
# <a href="https://colab.research.google.com/github/teejx/CCMACLRL_EXERCISES_COM222ML/blob/main/Exercise5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise 5

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from scipy.stats import pearsonr
import statsmodels.api as sm

# %%
df = pd.read_excel('traveldata.xlsx')

# %%
df

# %% [markdown]
# ## A. Correlation

# %% [markdown]
# ### Check the relationships between each independent variable and the dependent variable using scatterplots and correlations.

# %% [markdown]
# 1. Create scatter plot between miles traveled and travel time

# %%
# put your answer here
plt.scatter(df['Miles Traveled'], df['Travel Time'])
plt.xlabel('Miles Traveled')
plt.ylabel('Travel Time')
plt.show()

# %% [markdown]
# 2. Create scatter plot between number of deliveries and travel time

# %%
# put your answer here
plt.scatter(df['Number of Deliveries'], df['Travel Time'])
plt.xlabel('Number of Deliveries')
plt.ylabel('Travel Time')
plt.show()

# %% [markdown]
# 3. Create scatter plot between Gas Price and Travel time

# %%
# put your answer here
plt.scatter(df['Gas Price'], df['Travel Time'])
plt.xlabel('Gas Price')
plt.ylabel('Travel Time')
plt.show()

# %% [markdown]
# 4. Create a pairplot

# %%
# put your answer here
sns.pairplot(df)
plt.show()

# %%
sns.set_palette("husl")
sns.pairplot(data=df[['Miles Traveled','Number of Deliveries', 'Travel Time' ]], height=2)

# %% [markdown]
# 5. Calculate correlation coefficient and p-value between Miles Traveled and Travel Time

# %%
# put your answer here
result = pearsonr(df['Miles Traveled'], df['Travel Time'])
print('Miles Traveled and Travel Time"')
print('correlation coefficient:', result[0])
print('p-value:', result[1])
# Out:
# Miles Traveled and Travel Time"
# correlation coefficient: 0.928178500887476
# p-value: 0.00010667565429896801

# %% [markdown]
# 6. Calculate correlation coefficient and p-value between Number of Deliveries and Travel Time

# %%
# put your answer here
result = pearsonr(df['Number of Deliveries'], df['Travel Time'])
print('Number of Deliveries and Travel Time"')
print('correlation coefficient:', result[0])
print('p-value:', result[1])
# Out:
# Number of Deliveries and Travel Time"
# correlation coefficient: 0.9164433964470268
# p-value: 0.00019260878342962958

# %% [markdown]
# 7. Calculate correlation coefficient and p-value between Gas Price and Travel Time

# %%
# put your answer here
result = pearsonr(df['Gas Price'], df['Travel Time'])
print('Gas Price and Travel Time"')
print('correlation coefficient:', result[0])
print('p-value:', result[1])
# Out:
# Gas Price and Travel Time"
# correlation coefficient: 0.2672115310193847
# p-value: 0.45545341268508166

# %% [markdown]
# ### Check the relationships among the independent variables using scatterplots and correlations.

# %% [markdown]
# 8. Create scatter plot between Miles Traveled and Number of Deliveries.

# %%
# put your answer here
plt.scatter(df['Miles Traveled'], df['Number of Deliveries'])
plt.xlabel('Miles Traveled')
plt.ylabel('Number of Deliveries')
plt.show()

# %% [markdown]
# 9. Create scatter plot between Miles traveled and Gas Price

# %%
# put your answer here
plt.scatter(df['Miles Traveled'], df['Gas Price'])
plt.xlabel('Miles Traveled')
plt.ylabel('Gas Price')
plt.show()

# %% [markdown]
# 10. Create scatter plot between Number of Deliveries and Gas Price

# %%
# put your answer here
plt.scatter(df['Number of Deliveries'], df['Gas Price'])
plt.xlabel('Number of Deliveries')
plt.ylabel('Gas Price')
plt.show()

# %% [markdown]
# 11. Calculate r-squared and p-value between Miles Traveled and Number of Deliveries

# %%
# put your answer here
result = pearsonr(df['Miles Traveled'], df['Number of Deliveries'])
print('Miles Traveled and Number of Deliveries"')
print('correlation coefficient:', result[0])
print('p-value:', result[1])
# Out:
# Miles Traveled and Number of Deliveries"
# correlation coefficient: 0.9558982066200347
# p-value: 1.5690314407660616e-05

# %% [markdown]
# 12. Calculate r-squared and p-value between Miles Traveled and Gas Price

# %%
# put your answer here
result = pearsonr(df['Miles Traveled'], df['Gas Price'])
print('Miles Traveled and Gas Price"')
print('correlation coefficient:', result[0])
print('p-value:', result[1])
# Out:
# Miles Traveled and Gas Price"
# correlation coefficient: 0.35579623354708517
# p-value: 0.31296405908178965

# %% [markdown]
# 13. Calculate r-squared and p-value between Number of Deliveries and Gas Price

# %%
# put your answer here
result = pearsonr(df['Number of Deliveries'], df['Gas Price'])
print('Number of Deliveries and Gas Price"')
print('correlation coefficient:', result[0])
print('p-value:', result[1])
# Out:
# Number of Deliveries and Gas Price"
# correlation coefficient: 0.4982421647401633
# p-value: 0.142741207670319

# %% [markdown]
# ### Correlation Summary

# %% [markdown]
# 14. Create the correlation summary

# %%
# put your answer here
correlation = df.corr()
correlation.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_72149_row0_col0, #T_72149_row1_col1, #T_72149_row2_col2, #T_72149_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_72149_row0_col1 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_72149_row0_col2 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_72149_row0_col3 {
#   background-color: #d65244;
#   color: #f1f1f1;
# }
# #T_72149_row1_col0 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_72149_row1_col2 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_72149_row1_col3 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_72149_row2_col0, #T_72149_row2_col1, #T_72149_row2_col3, #T_72149_row3_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_72149_row3_col0 {
#   background-color: #d95847;
#   color: #f1f1f1;
# }
# #T_72149_row3_col1 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_72149" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_72149_level0_col0" class="col_heading level0 col0" >Miles Traveled</th>
#       <th id="T_72149_level0_col1" class="col_heading level0 col1" >Number of Deliveries</th>
#       <th id="T_72149_level0_col2" class="col_heading level0 col2" >Gas Price</th>
#       <th id="T_72149_level0_col3" class="col_heading level0 col3" >Travel Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_72149_level0_row0" class="row_heading level0 row0" >Miles Traveled</th>
#       <td id="T_72149_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_72149_row0_col1" class="data row0 col1" >0.955898</td>
#       <td id="T_72149_row0_col2" class="data row0 col2" >0.355796</td>
#       <td id="T_72149_row0_col3" class="data row0 col3" >0.928179</td>
#     </tr>
#     <tr>
#       <th id="T_72149_level0_row1" class="row_heading level0 row1" >Number of Deliveries</th>
#       <td id="T_72149_row1_col0" class="data row1 col0" >0.955898</td>
#       <td id="T_72149_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_72149_row1_col2" class="data row1 col2" >0.498242</td>
#       <td id="T_72149_row1_col3" class="data row1 col3" >0.916443</td>
#     </tr>
#     <tr>
#       <th id="T_72149_level0_row2" class="row_heading level0 row2" >Gas Price</th>
#       <td id="T_72149_row2_col0" class="data row2 col0" >0.355796</td>
#       <td id="T_72149_row2_col1" class="data row2 col1" >0.498242</td>
#       <td id="T_72149_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_72149_row2_col3" class="data row2 col3" >0.267212</td>
#     </tr>
#     <tr>
#       <th id="T_72149_level0_row3" class="row_heading level0 row3" >Travel Time</th>
#       <td id="T_72149_row3_col0" class="data row3 col0" >0.928179</td>
#       <td id="T_72149_row3_col1" class="data row3 col1" >0.916443</td>
#       <td id="T_72149_row3_col2" class="data row3 col2" >0.267212</td>
#       <td id="T_72149_row3_col3" class="data row3 col3" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# 15. Create a correlation matrix

# %%
# put your answer here
sns.heatmap(correlation, annot=True, vmin=1, vmax=1, center=0)
plt.show()

# %% [markdown]
# ## Building Different Regression Models

# %% [markdown]
# ### Model 1: Miles Traveled and Travel Time

# %% [markdown]
# 16. Set independent and dependent variables

# %%
# put your answer here
X = df[['Miles Traveled','Number of Deliveries','Gas Price']]
X = sm.add_constant(X)
y = df['Travel Time']

# %% [markdown]
# 17. Build and train the model

# %%
# put your answer here
mlr_model = LinearRegression()
mlr_model.fit(X, y)

y_pred = mlr_model.predict(X)
print('Intercept:', mlr_model.intercept_)
print('Coefficient:', mlr_model.coef_)
# Out:
# Intercept: 6.211377663979402
# Coefficient: [ 0.          0.01412189  0.38315024 -0.60655271]

# %% [markdown]
# 18. Display the statistical summary

# %%
# put your answer here
X = sm.add_constant(X)
model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            Travel Time   R-squared:                       0.895
# Model:                            OLS   Adj. R-squared:                  0.842
# Method:                 Least Squares   F-statistic:                     16.99
# Date:                Fri, 06 Sep 2024   Prob (F-statistic):            0.00245
# Time:                        09:33:46   Log-Likelihood:               -0.98426
# No. Observations:                  10   AIC:                             9.969
# Df Residuals:                       6   BIC:                             11.18
# Df Model:                           3
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    6.2114      2.321      2.677      0.037       0.533      11.890
# Miles Traveled           0.0141      0.022      0.636      0.548      -0.040       0.068
# Number of Deliveries     0.3832      0.300      1.277      0.249      -0.351       1.117
# Gas Price               -0.6066      0.527     -1.152      0.293      -1.895       0.682
# ==============================================================================
# Omnibus:                        2.874   Durbin-Watson:                   2.406
# Prob(Omnibus):                  0.238   Jarque-Bera (JB):                1.204
# Skew:                           0.457   Prob(JB):                        0.548
# Kurtosis:                       1.567   Cond. No.                     1.79e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.79e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_axis_nan_policy.py:531: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   res = hypotest_fun_out(*samples, **kwds)

# %%
olsmod = sm.OLS(y, X).fit()
olsmod.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_axis_nan_policy.py:531: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   res = hypotest_fun_out(*samples, **kwds)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            Travel Time   R-squared:                       0.895
# Model:                            OLS   Adj. R-squared:                  0.842
# Method:                 Least Squares   F-statistic:                     16.99
# Date:                Fri, 06 Sep 2024   Prob (F-statistic):            0.00245
# Time:                        09:33:48   Log-Likelihood:               -0.98426
# No. Observations:                  10   AIC:                             9.969
# Df Residuals:                       6   BIC:                             11.18
# Df Model:                           3
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    6.2114      2.321      2.677      0.037       0.533      11.890
# Miles Traveled           0.0141      0.022      0.636      0.548      -0.040       0.068
# Number of Deliveries     0.3832      0.300      1.277      0.249      -0.351       1.117
# Gas Price               -0.6066      0.527     -1.152      0.293      -1.895       0.682
# ==============================================================================
# Omnibus:                        2.874   Durbin-Watson:                   2.406
# Prob(Omnibus):                  0.238   Jarque-Bera (JB):                1.204
# Skew:                           0.457   Prob(JB):                        0.548
# Kurtosis:                       1.567   Cond. No.                     1.79e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.79e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# 19. Display the r-squared

# %%
# put your answer here
print('R-squared:', model.rsquared)
# Out:
# R-squared: 0.8946842692569462

# %%
print(olsmod.rsquared)
# Out:
# 0.8946842692569462
